# %% [markdown]
# # Package installation instructions
#
# Open a terminal window and type:
#
# jupyter notebook

# %% [markdown]
# ### 1. Check where you are in the system. You can use bash commands in a jupyter notebook with "!", e.g.

# %%
# !pwd
# Out:
# /Users/webb/Documents

# %% [markdown]
# ### 2. Check python and conda version

# %%
# !python --version
# !conda --version
# Out:
# Python 3.7.10
# conda 4.10.3

# %% [markdown]
# ### 3. Let us create a new conda environment for this course:
#
# This is advisable even if you already have a conda environment running in your laptop because we can install all the libraries we need in a single place without interferring with otehr environments.
#
# See documentation here: https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html

# %%
# !conda create -n py38 python=3.8 anaconda -y
# Out:
# ...
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/webb/opt/anaconda3/envs/py38
#
#   added / updated specs:
#     - anaconda
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alabaster-0.7.12           |     pyhd3eb1b0_0          16 KB
#     anaconda-2021.05           |           py38_0          16 KB
#     anaconda-client-1.7.2      |           py38_0         154 KB
#     anaconda-project-0.9.1     |     pyhd3eb1b0_1         215 KB
#     anyio-2.2.0                |   py38hecd8cb5_1         124 KB
#     appdirs-1.4.4              |             py_0          13 KB
#     appnope-0.1.2              |py38hecd8cb5_1001          10 KB
#     appscript-1.1.2            |   py38h9ed2024_0         129 KB
# ...

# %% [markdown]
# ### 4. To check the installation went well, type the following.
#
# The * indicates which environment you are using.

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/webb/opt/anaconda3
# py27                     /Users/webb/opt/anaconda3/envs/py27
# py37                  *  /Users/webb/opt/anaconda3/envs/py37
# py38                     /Users/webb/opt/anaconda3/envs/py38

# %% [markdown]
# ### 5. Close notebook, open a terminal and type
#
# conda activate py38
#
# jupyter notebook
#
# Then, check environment again. You should see that the * moved to py38

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/webb/opt/anaconda3
# py27                     /Users/webb/opt/anaconda3/envs/py27
# py37                     /Users/webb/opt/anaconda3/envs/py37
# py38                  *  /Users/webb/opt/anaconda3/envs/py38

# %% [markdown]
# ### 6. Now, let's install a few libraries within py38.
#
# These libraries are needed for the exercises, so please make sure they are properly installed.

# %%
# !python --version

# !conda install git numpy scipy matplotlib h5py imageio scikit-image pandas astropy yt anaconda -y
# Out:
# Python 3.8.8
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/webb/opt/anaconda3/envs/py38
#
#   added / updated specs:
#     - anaconda
#     - astropy
#     - git
#     - h5py
#     - imageio
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-image
#     - scipy
#     - yt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     anaconda-custom            |           py38_1          35 KB
#     astropy-4.3.1              |   py38hf9932de_0         6.3 MB
#     certifi-2021.5.30          |   py38hecd8cb5_0         139 KB
#     libllvm9-9.0.1             |       h21ff451_1        15.4 MB
#     pandas-1.3.2               |   py38h5008ddb_0         9.1 MB
#     pathtools-0.1.2            |     pyhd3eb1b0_1           9 KB
# ...

# %% [markdown]
# ### 7. You should be able to see the installed libraries in your py38 environment

# %%
# !conda list
# Out:
# # packages in environment at /Users/webb/opt/anaconda3/envs/py38:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.07                  py38_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  custom                   py38_1
# anaconda-client           1.7.2                    py38_0
# anaconda-project          0.9.1              pyhd3eb1b0_1
# anyio                     2.2.0            py38hecd8cb5_1
# appdirs                   1.4.4                      py_0
# applaunchservices         0.2.1                      py_0
# appnope                   0.1.2           py38hecd8cb5_1001
# appscript                 1.1.2            py38h9ed2024_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38h9ed2024_1
# asn1crypto                1.4.0                      py_0
# astroid                   2.5              py38hecd8cb5_1
# ...

# %% [markdown]
# ### 8. Specific versions are sometimes needed and they are only available in some channels
#
# You can specify them during installation with -c

# %%
# !conda install -c conda-forge vtk anaconda -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/webb/opt/anaconda3/envs/py38
#
#   added / updated specs:
#     - anaconda
#     - vtk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.0               |       he49afe7_0         920 KB  conda-forge
#     certifi-2021.5.30          |   py38h50d1736_0         141 KB  conda-forge
#     h5py-2.10.0                |nompi_py38h106b333_102        1022 KB  conda-forge
#     hdf4-4.2.15                |       hefd3b78_3         885 KB  conda-forge
#     hdf5-1.10.5                |nompi_h0cbb7df_1103         2.7 MB  conda-forge
#     jpeg-9d                    |       hbcb3906_0         250 KB  conda-forge
#     jsoncpp-1.8.4              |    ha1b3eb9_1002         167 KB  conda-forge
#     libcxx-12.0.1              |       habf9029_0         1.1 MB  conda-forge
# ...

# %% [markdown]
# ### 9. And to double check:

# %%
# !conda list vtk
# Out:
# # packages in environment at /Users/webb/opt/anaconda3/envs/py38:
# #
# # Name                    Version                   Build  Channel
# vtk                       8.2.0           py38h5052d89_214    conda-forge

# %% [markdown]
# ### 10. Now, let's make a simple plot

# %%
# Importing libraries, # can be used to comment your code
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# The first line forces the notebook to display figures on screen.

# %matplotlib inline   

# Create x
x = np.arange(-2*math.pi,+2*math.pi,0.001)

# Plot sin(x) vs. x
plt.plot(x,np.sin(x))

# %% [markdown]
# ## We are ready for science!
