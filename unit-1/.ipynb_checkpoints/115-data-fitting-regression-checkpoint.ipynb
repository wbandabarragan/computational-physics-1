# %% [markdown]
# # Data fitting and regression

# %% [markdown]
# Let us imagine we measure the thickness of a book for different number of pages. We count the number of pages (variable book pages) and use a Vernier to measure the thickness in units of $\rm mm$.
#
# Then, we save the experimental data into a file named: **"books.dat"**

# %% [markdown]
# ## Data input using Pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# read_csv returns a DataFrame, which is two-dimensional data structure with labeled axes.

data = pd.read_csv("books.dat", sep = "\s+")
print(data) # Uncomment to print data

# To get the data from specific columns, you can use their respective keys, e.g.:

N = data["N"]
pages = data["Pages"]
thickness = data["Thickness"]
# Out:
#     N  Pages  Thickness
# 0   1     10        3.0
# 1   2     20        4.5
# 2   3     30        5.5
# 3   4     40        7.0
# 4   5     50        8.0
# 5   6     60        9.0
# 6   7     70        9.5
# 7   8     80       11.1
# 8   9     90       12.0
# 9  10    100       12.9

# %% [markdown]
# ## Plotting with Matplotlib

# %%
# And now we plot
fig, ax = plt.subplots()

ax.plot(pages,thickness,color='red', marker = "d", linestyle=" ", label="thickness vs. pages")
ax.set_xlabel('Pages')
ax.set_ylabel('Thickness [mm]')
ax.legend()
plt.show()

# %% [markdown]
# ## Linear regression

# %% [markdown]
# We usually need a model when we want to do perform a regression. In this case, it is reasonable to use a line since we expect the number of pages and the tickness are linearly correlated.
#
# Our model is then:
#
# $\rm thickness = a\,(\rm pages)+b $
#
# Note that $\rm a$ and $\rm b$ have units of $\rm mm/page$ and $\rm mm$, respectively.

# %% [markdown]
# ### 1. Using np.polyfit()
#
# - np.polyfit() returns the coefficients **a** nd **b**.
#
# See the documentation here:
#
# https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html

# %%
# Get coefficients

a, b = np.polyfit(pages, thickness, 1)

# Print to check
print('slope =', a, ' intercept=', b)

# Get fitting function
fit_thickness = a*pages + b
# Out:
# slope = 0.10793939393939393  intercept= 2.31333333333333

# %%
# Now we plot the data and the fit
fig, ax = plt.subplots()

ax.plot(pages,thickness,color='red', marker = "d", linestyle=" ", linewidth=3, label="thickness vs. pages") 
ax.plot(pages,fit_thickness,color='blue', linestyle="-", linewidth=3, label="fit") 
ax.set_xlabel('Pages')
ax.set_ylabel('Thickness [mm]')
ax.legend()
plt.show()

# %% [markdown]
# ### 2. Using Scipy functions
#
#
# The function curve_fit() from the scipy.optimize package can be used.
#
# See documentation here: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html

# %%
from scipy.optimize import curve_fit

# %%
#define a function to fit to the data
def func(x, a, b):
    return a * x + b

# %%
# Call curve_fit()

coef, cova = curve_fit(func, pages, thickness)

#print(coef, cova)

print('thickness = %.5f * pages + %.5f' % (coef[0], coef[1]))
# Out:
# thickness = 0.10794 * pages + 2.31333

# %%
# Define new function

fit_pages2 = func(pages, *coef)

# %%
# And now we plot
fig, ax = plt.subplots()

ax.plot(pages,thickness,color='red', marker = "d", linestyle=" ", linewidth=3, label="thickness vs. pages") 
ax.plot(pages,fit_pages2,color='blue', linestyle="-", linewidth=3, label="scipy fit") 
ax.set_xlabel('Pages')
ax.set_ylabel('Thickness [mm]')
ax.legend()
plt.show()

# %% [markdown]
# ### Pearson 'r' coefficient
#
# The Pearson correlation coefficient (r) is an indicator of how strong a linear correlation between 2 variables is.
#
#
# It can take values between -1 and 1.

# %%
# calculate Pearson's r correlation coeficient
from scipy.stats import spearmanr, pearsonr

p1 = pearsonr(pages, thickness)

print('Pearson r coefficients:', p1)
# Out:
# Pearson r coefficients: (0.9967647822032424, 4.774249416992817e-10)

# %%
sigma_err = np.sqrt(np.diag(cova))
print(sigma_err)
# Out:
# [0.00307721 0.19093602]

# %% [markdown]
# ### Spearman's coefficient
#
# The Spearman correlation evaluates the monotonic relationship between 2 variables.
#
#
# Linearity is not essential.
#
#
# A monotonic relationship between 2 variables implies one of two situations:
#
#
# - (Situation 1) As the value of one variable increases, so does the value of the other variable, OR,
#
# - (Situation 2) As the value of one variable increases, the other variable value decreases.
#
#
# Not necessarily at a constant rate.

# %%
# calculate Spearman's r correlation coeficient

p = spearmanr(pages, thickness)

print('Spearman values:', p)
# Out:
# Spearman values: SpearmanrResult(correlation=0.9999999999999999, pvalue=6.646897422032013e-64)

# %% [markdown]
# ## Adding regression error bars

# %%
# Another way
# Using poly1d()
# See documentation: https://numpy.org/doc/stable/reference/generated/numpy.poly1d.html

coef = np.polyfit(pages, thickness, 1)

poly1d_fn = np.poly1d(coef)  # to create a linear function with coefficients

plt.plot(pages, thickness, '+', pages, poly1d_fn(pages), '-b')
plt.errorbar(pages, poly1d_fn(pages), yerr=poly1d_fn(pages) - thickness, fmt='.k')
plt.show()

# %% [markdown]
# ## Exercise: meteorological data
#
# - We will analyse data taken from the World Meteorological Organisation (WMO).
#
# - Data are written in json files with the following structure.
#
# https://worldweather.wmo.int/en/json/WWIS_json_schema_v2.json
#
# - Python has an in-built function to read json files.

# %%
# Python program to read a json file
import json

# JSON file
f = open('291_en.json', "r")

# Reading from file
data = json.loads(f.read())

#print(data["city"]["climate"]["climateMonth"][0])

month   = []
minTemp = []
maxTemp = []
rainfall= []

for i in range (len(data["city"]["climate"]["climateMonth"])):
    month.append(data["city"]["climate"]["climateMonth"][i]["month"])
    minTemp.append(float(data["city"]["climate"]["climateMonth"][i]["minTemp"]))    
    maxTemp.append(float(data["city"]["climate"]["climateMonth"][i]["maxTemp"]))
    rainfall.append(float(data["city"]["climate"]["climateMonth"][i]["rainfall"]))
#    print(data["city"]["climate"]["climateMonth"][i]["maxTemp"])

# Closing file
f.close()


#print(month)
#print(maxTemp)
#print(rainfall)

# %%
# %matplotlib inline

plt.plot(np.array(month),np.array(maxTemp), marker = 'd', linestyle = '-.')

# %%
plt.plot(np.array(month),np.array(rainfall), marker = 'd', linestyle = '-')

# %%
plt.plot(np.array(month),np.array(maxTemp)/np.max(maxTemp), marker = 'd', linestyle = '-.')
plt.plot(np.array(month),np.array(rainfall)/np.max(rainfall), marker = 'd', linestyle = '-')

# %%
plt.plot(np.array(maxTemp),np.array(rainfall), marker = 'd', linestyle = '')

# %%
plt.plot(np.array(minTemp),np.array(rainfall), marker = 'd', linestyle = '')

# %%
# calculate Pearson's r correlation coeficient
from scipy.stats import spearmanr, pearsonr

p = spearmanr(np.array(minTemp), np.array(rainfall))

p1 = pearsonr(np.array(minTemp), np.array(rainfall))

print('Spearman values:', p)

print('Pearson r coefficients:', p1)
# Out:
# Spearman values: SpearmanrResult(correlation=0.6053561964006321, pvalue=0.036995534708780774)
# Pearson r coefficients: (0.6635078693465295, 0.018651930806838496)

# %%
#define a function to fit to the data
def func(x, a, b):
    return a*x + b

# %%
A=np.polyfit(minTemp, rainfall, 1)
print(A)
# Out:
# [ 105.100271   -935.83848238]

# %%
plt.plot(np.array(minTemp),np.array(rainfall), marker = 'd', linestyle = '')

line = np.array(sorted(minTemp))

print(type(line))

plt.plot(line,func(line,A[0],A[1]), linestyle = '-.')
# Out:
# <class 'numpy.ndarray'>
