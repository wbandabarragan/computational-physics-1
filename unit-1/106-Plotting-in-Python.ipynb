# %% [markdown]
# <a href="https://colab.research.google.com/github/wbandabarragan/computational-physics-1/blob/main/unit-1/106-Plotting-in-Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting in Python
#
# We will use mainly Matplotlib for plotting: https://matplotlib.org/
#
# Some examples on how to use Matplotlib for plotting cane be found here:
#
# https://matplotlib.org/tutorials/introductory/sample_plots.html
#
# https://matplotlib.org/gallery/index.html
#
# Other examples can be found on forums, e.g. StackOverflow:
#
# https://stackoverflow.com/
#
# Asking questions on Google is also very helpful as there are many links, examples, solutions to problems, etc.
#
# Python is a community-developed language, so you are also welcome to report bugs:
#
# https://bugs.python.org/
#
#
# ## Matplotlib
#
# It is a library used for visualization with Python.
# It allows users to create static, animated, and interactive plots.
#
# "It makes easy things easy and hard things possible." (from Matplotlib website)
# Customising plots is easy. The documentation is comprehensive and easy to find.
#
# ### pyplot():
# Basic plotting with pyplot
#
# Pyplot is an interface to plot using Matlab- and Mathematica-like plotting sequences.
#
# It facilitates plotting.
# Plotting can be done without using "objects", e.g.

# %% [markdown]
# ## 1. Inline plotting:

# %%
# Import third-party libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# This line is added for inline, interactive plotting
# %matplotlib inline

# Generate a couple of vectors
x = np.arange(0, 6*np.pi, 0.01)

y = np.sin(x)

# Plotting
plt.plot(x,y)

# %% [markdown]
# ## 2. Figure environments:
#
# - This refers to code lines that open, plot and show the figure.

# %%
# The basic syntax for a fig. env.

# Open env.
plt.figure()

# Plot
plt.plot(x,y)

# Show/Save
plt.show()
# plt.savefig()

# In actual code, we should always clean up the memory
# plt.close()

# %%
# Customise our figures:

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":")

# Title with latex syntax
plt.title(r"$\sin(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y=\sin(x)$")

# Show/Save
plt.show()

# %% [markdown]
# ## This is only for Google Colab.
#
# In Google Colab, we need to mount the Google Drive folder where we want to save anything.

# %%
# Import Google Drive capabilities
from google.colab import drive

# Mount the Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive
# Out:
# MyDrive  Shareddrives

# %%
# !ls /content/drive/MyDrive/'Colab Notebooks'
# Out:
#  101-Introduction-GoogleColab.ipynb	 homework001_solutions.ipynb
#  104-python-basics-review.ipynb		 homework-01.ipynb
#  105-numpy-arrays.ipynb			 homework-04.ipynb
#  106-Plotting-in-Python.ipynb		 Obsolete
#  107-predictor-corrector-methods.ipynb	 Python-Notebok-401.ipynb
#  AM0AM1_5.csv				 Python-Notebook-203.ipynb
#  classwork001_solutions.ipynb		 QM0.ipynb
#  classwork-01.ipynb			 QM5.ipynb
#  classwork-02.ipynb			 QM6.ipynb
#  classwork-03-solutions.ipynb		 QM-infinite-square-well.ipynb
# 'classwork-04 (1).ipynb'		 summary-wavefunctions2.ipynb
#  classwork-04.ipynb			 summary-wavefunctions.ipynb
#  data-photoelectric.csv			 Untitled0.ipynb
#  final-exam.ipynb

# %%
# Customise our figures:

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":")

# Title with latex syntax
plt.title(r"$\sin(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y=\sin(x)$")

# Show/Save
plt.savefig("/content/drive/MyDrive/Colab Notebooks/sine.png")

# %%
# Customise our figures:

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":")

# Title with latex syntax
plt.title(r"$\sin(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y=\sin(x)$")

# Show/Save
plt.savefig("/content/drive/MyDrive/Colab Notebooks/sine.eps")

# %% [markdown]
# ## Example: overplotting

# %%
# Superimpose plots:

w = np.cos(x)

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":", label = r"$\sin(x)$")
plt.plot(x, w, color = "green", linestyle = "-.", label = r"$\cos(x)$")

# Title with latex syntax
plt.title(r"$\sin(x)$ and $\cos(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y,w$")

# Legend is added with loc for location
plt.legend(loc=3)

# Show/Save
plt.show()
