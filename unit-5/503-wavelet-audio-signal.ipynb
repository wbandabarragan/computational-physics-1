# %% [markdown]
# # DWT Application Example: Audio file
#
# Download a .wav file.
#
# Decompose the signal in low and high frequencies by using DWT.
#
# Then write the following files:
#
# 1. The fully reconstructed signal from the approximation and detail coefficients.
#
#
# 2. The low-frequency signal considering the approximation coefficients only.
#
#
# 3. The high-frequency signal considering the detail coefficients only.
#
#
# 4. Listen to all three audio tracks and compare them to the original one. What do you find?
#
# ### Reference file:
# https://github.com/wbandabarragan/physics-teaching-data/blob/main/1D-data/ImperialMarch60.wav

# %%
from scipy.io import wavfile

import IPython.display as ipd

import numpy as np

import matplotlib.pyplot as plt

import pywt

# %% [markdown]
# ### Read wav file:

# %%
# Define file path

filepath = "./"

# File I/O 
#samplerate, data = wavfile.read(filepath + "ImperialMarch60.wav")

# %%
# Check the signal

print(type(samplerate))

print(data.shape)

print(data, np.min(data), np.max(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Check the signal
# ----> 3 print(type(samplerate))
#       5 print(data.shape)
#       7 print(data, np.min(data), np.max(data))
#
# NameError: name 'samplerate' is not defined

# %%
ipd.Audio(filepath + "ImperialMarch60.wav")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ipd.Audio(filepath + "ImperialMarch60.wav")
#
# File /opt/anaconda3/envs/py311/lib/python3.11/site-packages/IPython/lib/display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %% [markdown]
# ### Define x and y axes:

# %%
# Generate the time axis using the sampling rate
t = np.arange(len(data))/float(samplerate)

# Normalising the signal
data = data/np.max(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Generate the time axis using the sampling rate
# ----> 2 t = np.arange(len(data))/float(samplerate)
#       4 # Normalising the signal
#       5 data = data/np.max(data)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### Plot signal:

# %%
# Plotting the audio track

plt.figure(figsize=(11,3))

plt.plot(t, data)

plt.xlabel(r"$t$")
plt.ylabel(r"$I$")
#plt.xlim(0,2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Plotting the audio track
#       3 plt.figure(figsize=(11,3))
# ----> 5 plt.plot(t, data)
#       7 plt.xlabel(r"$t$")
#       8 plt.ylabel(r"$I$")
#
# NameError: name 't' is not defined

# %%
# Plotting the audio track

plt.figure(figsize=(11,4))

plt.plot(t, data)
plt.xlim(15.5,15.6)

plt.xlabel(r"$t$")
plt.ylabel(r"$I$")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 # Plotting the audio track
#       3 plt.figure(figsize=(11,4))
# ----> 5 plt.plot(t, data)
#       6 plt.xlim(15.5,15.6)
#       8 plt.xlabel(r"$t$")
#
# NameError: name 't' is not defined

# %% [markdown]
# ### DWT to get coefficients:

# %%
cA, cD = pywt.dwt(data, 'bior6.8', 'per')

print(cA.shape, cD.shape, data.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cA, cD = pywt.dwt(data, 'bior6.8', 'per')
#       3 print(cA.shape, cD.shape, data.shape)
#
# NameError: name 'data' is not defined

# %%
# Applying the iDWT
data_reconstruted = pywt.idwt(cA, cD, 'bior6.8', 'per')

# Saving the reconstructed file
wavfile.write(filepath + 'full_reconstructed.wav', samplerate, data_reconstruted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Applying the iDWT
# ----> 2 data_reconstruted = pywt.idwt(cA, cD, 'bior6.8', 'per')
#       4 # Saving the reconstructed file
#       5 wavfile.write(filepath + 'full_reconstructed.wav', samplerate, data_reconstruted)
#
# NameError: name 'cA' is not defined

# %%
#wavfile.write('../sample-data/reconstructed.wav', samplerate, data_reconstruted)

# %% [markdown]
# ### Comparing the original and the reconstructured signals:

# %%
plt.figure(figsize=(11,4))

plt.plot(t, data, "blue")
plt.plot(t, data_reconstruted, linestyle = ":", c="yellow")
plt.xlim(15.5,15.6)

plt.xlabel(r"$t$")
plt.ylabel(r"$I$")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 plt.figure(figsize=(11,4))
# ----> 3 plt.plot(t, data, "blue")
#       4 plt.plot(t, data_reconstruted, linestyle = ":", c="yellow")
#       5 plt.xlim(15.5,15.6)
#
# NameError: name 't' is not defined

# %%
samplerate1, data1 = wavfile.read(filepath + "full_reconstructed.wav")

print(samplerate1)

print(data1.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 samplerate1, data1 = wavfile.read(filepath + "full_reconstructed.wav")
#       3 print(samplerate1)
#       5 print(data1.shape)
#
# File /opt/anaconda3/envs/py311/lib/python3.11/site-packages/scipy/io/wavfile.py:715, in read(filename, mmap)
#     713     mmap = False
#     714 else:
# --> 715     fid = open(filename, 'rb')
#     717 if not (was_seekable := fid.seekable()):
#     718     fid = SeekEmulatingReader(fid)
#
# FileNotFoundError: [Errno 2] No such file or directory: './full_reconstructed.wav'

# %%
ipd.Audio(filepath + "full_reconstructed.wav")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ipd.Audio(filepath + "full_reconstructed.wav")
#
# File /opt/anaconda3/envs/py311/lib/python3.11/site-packages/IPython/lib/display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %% [markdown]
# #### Isolate the low frequencies (Approximation coefficients)

# %%
# Saving the low freq. directly
wavfile.write(filepath + 'only_ca.wav', samplerate, cA) 

# 2nd try:
data_low = pywt.idwt(cA, None, "bior6.8", "per")

# Formatting: https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.wavfile.read.html

data_low_f = np.clip(data_low, -1., +1.).astype(np.float32)
 
wavfile.write(filepath + 'only_ca2.wav', samplerate, data_low)
wavfile.write(filepath + 'only_ca3.wav', samplerate, data_low_f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Saving the low freq. directly
# ----> 2 wavfile.write(filepath + 'only_ca.wav', samplerate, cA)
#       4 # 2nd try:
#       5 data_low = pywt.idwt(cA, None, "bior6.8", "per")
#
# NameError: name 'samplerate' is not defined

# %%
ipd.Audio(filepath + "only_ca3.wav")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ipd.Audio(filepath + "only_ca3.wav")
#
# File /opt/anaconda3/envs/py311/lib/python3.11/site-packages/IPython/lib/display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %% [markdown]
# #### Isolate the high frequencies (Approximation coefficients)

# %%
# Saving the low freq. directly
wavfile.write(filepath + 'only_cd.wav', samplerate, cD) 


# 2nd try:
data_high = pywt.idwt(None, cD, "bior6.8", "per")

# Formatting: https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.wavfile.read.html

data_high_f = np.clip(data_high, -1., +1.).astype(np.float32)

wavfile.write(filepath + 'only_cd2.wav', samplerate, data_high)
wavfile.write(filepath + 'only_cd3.wav', samplerate, data_high_f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Saving the low freq. directly
# ----> 2 wavfile.write(filepath + 'only_cd.wav', samplerate, cD)
#       5 # 2nd try:
#       6 data_high = pywt.idwt(None, cD, "bior6.8", "per")
#
# NameError: name 'samplerate' is not defined

# %%
ipd.Audio(filepath + "only_cd3.wav")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ipd.Audio(filepath + "only_cd3.wav")
#
# File /opt/anaconda3/envs/py311/lib/python3.11/site-packages/IPython/lib/display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %% [markdown]
# #wavfile.write('../sample-data/with_only_cds.wav', samplerate, cD) #high freq.

# %% [markdown]
# ### Alternative decomposition with pywt.wavedec():

# %%
coeffs_audio = pywt.wavedec(data, 'bior6.8', level = 2, mode = 'periodic')

#print(len(coeffs_audio))

ca, cd2, cd1 = coeffs_audio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 coeffs_audio = pywt.wavedec(data, 'bior6.8', level = 2, mode = 'periodic')
#       3 #print(len(coeffs_audio))
#       5 ca, cd2, cd1 = coeffs_audio
#
# NameError: name 'data' is not defined

# %%
print("Second level cA: ", ca.shape)
print("First level cD1: ",  cd1.shape)
print("Second level cD2: ", cd2.shape)
#print(cd3.shape)
#print(cd4.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print("Second level cA: ", ca.shape)
#       2 print("First level cD1: ",  cd1.shape)
#       3 print("Second level cD2: ", cd2.shape)
#
# NameError: name 'ca' is not defined

# %% [markdown]
# ### Recovering the original signal with pywt.waverec()

# %%
# Let's get the original signal again:

recovered_audio = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Let's get the original signal again:
# ----> 3 recovered_audio = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
#
# NameError: name 'coeffs_audio' is not defined

# %%
wavfile.write(filepath + 'full_reconstructed2.wav', samplerate, recovered_audio)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 wavfile.write(filepath + 'full_reconstructed2.wav', samplerate, recovered_audio)
#
# NameError: name 'samplerate' is not defined

# %% [markdown]
# ### Only using cA (2nd level):

# %%
print(len(coeffs_audio))
#print(coeffs_audio[-2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(len(coeffs_audio))
#       2 #print(coeffs_audio[-2])
#
# NameError: name 'coeffs_audio' is not defined

# %%
# Removing the second level detail coefficients
coeffs_audio[-2] = np.zeros_like(coeffs_audio[-2])

# Removing the first level detail coefficients
coeffs_audio[-1] = np.zeros_like(coeffs_audio[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Removing the second level detail coefficients
# ----> 2 coeffs_audio[-2] = np.zeros_like(coeffs_audio[-2])
#       4 # Removing the first level detail coefficients
#       5 coeffs_audio[-1] = np.zeros_like(coeffs_audio[-1])
#
# NameError: name 'coeffs_audio' is not defined

# %%
# Only cA coeff.

recovered_audio_ca = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Only cA coeff.
# ----> 3 recovered_audio_ca = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
#
# NameError: name 'coeffs_audio' is not defined

# %%
wavfile.write(filepath + 'rec_ca2.wav', samplerate, recovered_audio_ca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 wavfile.write(filepath + 'rec_ca2.wav', samplerate, recovered_audio_ca)
#
# NameError: name 'samplerate' is not defined

# %% [markdown]
# ### Alternative decomposition with pywt.wavedec():

# %%
coeffs_audio = pywt.wavedec(data, 'bior6.8', level = 3, mode = 'periodic')

print(len(coeffs_audio))

ca, cd3, cd2, cd1 = coeffs_audio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 coeffs_audio = pywt.wavedec(data, 'bior6.8', level = 3, mode = 'periodic')
#       3 print(len(coeffs_audio))
#       5 ca, cd3, cd2, cd1 = coeffs_audio
#
# NameError: name 'data' is not defined

# %%
print("Third level cA: ", ca.shape)
print("First level cD1: ",  cd1.shape)
print("Second level cD2: ", cd2.shape)
print("Third level cD3: ", cd3.shape)
#print(cd3.shape)
#print(cd4.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print("Third level cA: ", ca.shape)
#       2 print("First level cD1: ",  cd1.shape)
#       3 print("Second level cD2: ", cd2.shape)
#
# NameError: name 'ca' is not defined

# %%
# Removing the third level detail coefficients
coeffs_audio[-3] = np.zeros_like(coeffs_audio[-3])

# Removing the second level detail coefficients
coeffs_audio[-2] = np.zeros_like(coeffs_audio[-2])

# Removing the first level detail coefficients
coeffs_audio[-1] = np.zeros_like(coeffs_audio[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Removing the third level detail coefficients
# ----> 2 coeffs_audio[-3] = np.zeros_like(coeffs_audio[-3])
#       4 # Removing the second level detail coefficients
#       5 coeffs_audio[-2] = np.zeros_like(coeffs_audio[-2])
#
# NameError: name 'coeffs_audio' is not defined

# %%
# Only cA coeff.

recovered_audio_ca = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Only cA coeff.
# ----> 3 recovered_audio_ca = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
#
# NameError: name 'coeffs_audio' is not defined

# %%
wavfile.write(filepath + 'rec_ca3.wav', samplerate, recovered_audio_ca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 wavfile.write(filepath + 'rec_ca3.wav', samplerate, recovered_audio_ca)
#
# NameError: name 'samplerate' is not defined

# %% [markdown]
# ### Reconstructing third level high-freq components:

# %%
coeffs_audio = pywt.wavedec(data, 'bior6.8', level = 3, mode = 'periodic')

print(len(coeffs_audio))

ca, cd3, cd2, cd1 = coeffs_audio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 coeffs_audio = pywt.wavedec(data, 'bior6.8', level = 3, mode = 'periodic')
#       3 print(len(coeffs_audio))
#       5 ca, cd3, cd2, cd1 = coeffs_audio
#
# NameError: name 'data' is not defined

# %%
# Removing the third level approx coefficients
coeffs_audio[0] = np.zeros_like(coeffs_audio[0])

# Removing the second level detail coefficients
#coeffs_audio[-2] = np.zeros_like(coeffs_audio[-2])

# Removing the first level detail coefficients
#coeffs_audio[-1] = np.zeros_like(coeffs_audio[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Removing the third level approx coefficients
# ----> 2 coeffs_audio[0] = np.zeros_like(coeffs_audio[0])
#       4 # Removing the second level detail coefficients
#       5 #coeffs_audio[-2] = np.zeros_like(coeffs_audio[-2])
#       6
#       7 # Removing the first level detail coefficients
#       8 #coeffs_audio[-1] = np.zeros_like(coeffs_audio[-1])
#
# NameError: name 'coeffs_audio' is not defined

# %%
# Only cA coeff.

recovered_audio_ca = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Only cA coeff.
# ----> 3 recovered_audio_ca = pywt.waverec(coeffs_audio, 'bior6.8', mode = 'periodic')
#
# NameError: name 'coeffs_audio' is not defined

# %%
wavfile.write(filepath + 'rec_cd3.wav', samplerate, recovered_audio_ca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 wavfile.write(filepath + 'rec_cd3.wav', samplerate, recovered_audio_ca)
#
# NameError: name 'samplerate' is not defined
